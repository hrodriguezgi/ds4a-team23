# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import plotly.express as px
import folium


pd.options.display.max_columns = None

# %% [markdown]
# **Nota sobre los datasets**
# - El dataset de incidentes tiene valores faltantes en algunas categorias.
# - El dataset de incidentes tiene valores faltantes en la información de implicados de los ultimo 10_000 incidentes por falta del dataset de implicados.

# %%
agents = pd.read_csv("../0_datasets/processed/agents.csv.gz", parse_dates=["read_time", "time_stamp"])
incidents = pd.read_csv("../0_datasets/processed/incidents.csv.gz", parse_dates=["incident_time"])

# %%
incidents.sort_values(by="incident_time")
# Out:
#            id          source                      type    state  priority  \
# 2       10668            NUSE                    Choque  Cerrado       2.0
# 3       10668            NUSE                    Choque  Cerrado       2.0
# 0       10667            NUSE                    Choque  Cerrado       2.0
# 1       10667            NUSE                    Choque  Cerrado       2.0
# 4       10669            NUSE                    Choque  Cerrado       2.0
# ...       ...             ...                       ...      ...       ...
# 114256  76056            NUSE                    Choque  Cerrado       2.0
# 114254  76054  Semaforización  Mantenimiento correctivo  Cerrado       2.0
# 114057  75857  Semaforización          Falla de energía  Cerrado       1.0
# 80377   54239            NUSE                    Choque  Cerrado       2.0
# 80378   54239            NUSE                    Choque  Cerrado       2.0
#
#               gravity           class object  latitude  longitude  \
# ...

# %%
incidents["incident_time"].describe()
# Out:
# /tmp/ipykernel_5354/92185508.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   incidents["incident_time"].describe()
# count                  114257
# unique                  55405
# top       2022-05-23 10:53:00
# freq                       27
# first     2021-12-31 11:38:00
# last      2022-09-23 11:09:00
# Name: incident_time, dtype: object

# %%
incidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114257 entries, 0 to 114256
# Data columns (total 20 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               114257 non-null  int64
#  1   source           114257 non-null  object
#  2   type             114257 non-null  object
#  3   state            114257 non-null  object
#  4   priority         114256 non-null  float64
#  5   gravity          107805 non-null  object
#  6   class            114257 non-null  object
#  7   object           1723 non-null    object
#  8   latitude         114257 non-null  float64
#  9   longitude        114257 non-null  float64
#  10  location         114257 non-null  object
#  11  broker_id        42783 non-null   object
#  12  implicated       108523 non-null  float64
#  13  address          114257 non-null  object
#  14  zone_id          114257 non-null  object
#  15  orient           114257 non-null  object
# ...
