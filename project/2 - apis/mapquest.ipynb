# %% [markdown]
# # [MapQuest](https://www.mapquest.com/)
#
# Is an American free online web mapping service. It was launched in 1996 as the first commercial web mapping service. MapQuest vies for market share with competitors such as Google Maps and Here.
#
# There are different endpoints offered in their API.

# %%
import os 
import requests 
import json

# %%
key = os.getenv(KEY)

# %% [markdown]
# ### [Locations](https://developer.mapquest.com/documentation/common/forming-locations)

# %%
# Parque de la 93
location1 = '4.6767219,-74.0482788'
url_locations = f'http://www.mapquestapi.com/geocoding/v1/address?key={key}&location={location1}&thumbMaps=false'

r_url_locations = requests.get(url=url_locations)
r_url_locations_json = json.loads(r_url_locations.text)
r_url_locations_json
# Out:
# {'info': {'statuscode': 0,
#   'copyright': {'text': '© 2022 MapQuest, Inc.',
#    'imageUrl': 'http://api.mqcdn.com/res/mqlogo.gif',
#    'imageAltText': '© 2022 MapQuest, Inc.'},
#   'messages': []},
#  'options': {'maxResults': -1, 'thumbMaps': False, 'ignoreLatLngInput': False},
#  'results': [{'providedLocation': {'latLng': {'lat': 4.6767219,
#      'lng': -74.0482788}},
#    'locations': [{'street': 'Parque de la 93',
#      'adminArea6': '',
#      'adminArea6Type': 'Neighborhood',
#      'adminArea5': 'Chapinero',
#      'adminArea5Type': 'City',
#      'adminArea4': '',
#      'adminArea4Type': 'County',
#      'adminArea3': 'Bogota',
#      'adminArea3Type': 'State',
#      'adminArea1': 'CO',
#      'adminArea1Type': 'Country',
#      'postalCode': '110011',
#      'geocodeQualityCode': 'P1AAA',
#      'geocodeQuality': 'POINT',
#      'dragPoint': False,
#      'sideOfStreet': 'N',
#      'linkId': '0',
#      'unknownInput': '',
#      'type': 's',
#      'latLng': {'lat': 4.676753, 'lng': -74.048292},
#      'displayLatLng': {'lat': 4.676753, 'lng': -74.048292}}]}]}

# %%
# Parque Nacional
location2 = '4.6245251,-74.07462'
url_locations = f'http://www.mapquestapi.com/geocoding/v1/address?key={key}&location={location2}&thumbMaps=false'

r_url_locations = requests.get(url=url_locations)
r_url_locations_json = json.loads(r_url_locations.text)
r_url_locations_json
# Out:
# {'info': {'statuscode': 0,
#   'copyright': {'text': '© 2022 MapQuest, Inc.',
#    'imageUrl': 'http://api.mqcdn.com/res/mqlogo.gif',
#    'imageAltText': '© 2022 MapQuest, Inc.'},
#   'messages': []},
#  'options': {'maxResults': -1, 'thumbMaps': False, 'ignoreLatLngInput': False},
#  'results': [{'providedLocation': {'latLng': {'lat': 4.6245251,
#      'lng': -74.07462}},
#    'locations': [{'street': 'Calle 35',
#      'adminArea6': '',
#      'adminArea6Type': 'Neighborhood',
#      'adminArea5': 'Teusaquillo',
#      'adminArea5Type': 'City',
#      'adminArea4': '',
#      'adminArea4Type': 'County',
#      'adminArea3': 'Bogota',
#      'adminArea3Type': 'State',
#      'adminArea1': 'CO',
#      'adminArea1Type': 'Country',
#      'postalCode': '111311',
#      'geocodeQualityCode': 'B1AAA',
#      'geocodeQuality': 'STREET',
#      'dragPoint': False,
#      'sideOfStreet': 'N',
#      'linkId': '0',
#      'unknownInput': '',
#      'type': 's',
#      'latLng': {'lat': 4.624707, 'lng': -74.074591},
#      'displayLatLng': {'lat': 4.624707, 'lng': -74.074591}}]}]}

# %% [markdown]
# ## [Directions](https://developer.mapquest.com/documentation/directions-api/)
#
# The Directions API provides a simple interface to get routing, narrative, and shapes.

# %% [markdown]
# ### [Route](https://developer.mapquest.com/documentation/directions-api/route/get)
#
# The core and most basic function of our Directions API. Route provides information on how to get from point A to point B, or points C, D and E. Quite simply, it shows you and your users how to get where they are going.

# %%
# Parque de la 93
location1 = '4.6767219,-74.0482788'
# Parque Nacional
location2 = '4.6245251,-74.07462'

url_directions = f'http://www.mapquestapi.com/directions/v2/route?key={key}&from={location1}&to={location2}'
r_url_directions = requests.get(url=url_directions)
r_url_directions_json = json.loads(r_url_directions.text)
r_url_directions_json
# Out:
# {'route': {'hasTollRoad': False,
#   'hasBridge': False,
#   'boundingBox': {'lr': {'lng': -74.047066, 'lat': 4.622971},
#    'ul': {'lng': -74.0746, 'lat': 4.67639}},
#   'distance': 4.905,
#   'hasTimedRestriction': False,
#   'hasTunnel': False,
#   'hasHighway': True,
#   'computedWaypoints': [],
#   'routeError': {'errorCode': -400, 'message': ''},
#   'formattedTime': '00:10:11',
#   'sessionId': '6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#   'hasAccessRestriction': False,
#   'realTime': -1,
#   'hasSeasonalClosure': False,
#   'hasCountryCross': False,
#   'fuelUsed': 0.25,
#   'legs': [{'hasTollRoad': False,
#     'hasBridge': False,
#     'destNarrative': 'Proceed to CALLE 35.',
#     'distance': 4.905,
#     'hasTimedRestriction': False,
#     'hasTunnel': False,
#     'hasHighway': True,
#     'index': 0,
#     'formattedTime': '00:10:11',
#     'origIndex': 1,
#     'hasAccessRestriction': False,
#     'hasSeasonalClosure': False,
#     'hasCountryCross': False,
#     'roadGradeStrategy': [[]],
#     'destIndex': 3,
#     'time': 611,
#     'hasUnpaved': False,
#     'origNarrative': 'Go southwest on Carrera 11.',
#     'maneuvers': [{'distance': 0.108,
#       'streets': ['Calle 93A'],
#       'narrative': 'Start out going southeast on Calle 93A toward Carrera 12.',
#       'turnType': 0,
#       'startPoint': {'lng': -74.048462, 'lat': 4.67639},
#       'index': 0,
#       'formattedTime': '00:00:36',
#       'directionName': 'Southeast',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.676390171051025,-74.0484619140625|marker-1||4.675669193267822,-74.04706573486328|marker-2||&center=4.676029682159424,-74.04776382446289&defaultMarker=none&zoom=14&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 36,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-start_sm.gif',
#       'direction': 5},
#      {'distance': 1.507,
#       'streets': ['Carrera 11'],
#       'narrative': 'Turn right onto Carrera 11.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.047066, 'lat': 4.675669},
#       'index': 1,
#       'formattedTime': '00:03:23',
#       'directionName': 'Southwest',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.675669193267822,-74.04706573486328|marker-2||4.657280921936035,-74.05870819091797|marker-3||&center=4.666475057601929,-74.05288696289062&defaultMarker=none&zoom=9&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 203,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 6},
#      {'distance': 0.276,
#       'streets': ['Avenida Chile', 'Calle 72'],
#       'narrative': 'Turn right onto Avenida Chile/Calle 72.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.058708, 'lat': 4.657281},
#       'index': 2,
#       'formattedTime': '00:00:55',
#       'directionName': 'Northwest',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.657280921936035,-74.05870819091797|marker-3||4.659584999084473,-74.06198120117188|marker-4||&center=4.658432960510254,-74.06034469604492&defaultMarker=none&zoom=12&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 55,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 2},
#      {'distance': 2.596,
#       'streets': ['Avenida Caracas'],
#       'narrative': 'Turn left onto Avenida Caracas.',
#       'turnType': 6,
#       'startPoint': {'lng': -74.061981, 'lat': 4.659585},
#       'index': 3,
#       'formattedTime': '00:03:53',
#       'directionName': 'South',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.659584999084473,-74.06198120117188|marker-4||4.622971057891846,-74.06954193115234|marker-5||&center=4.641278028488159,-74.06576156616211&defaultMarker=none&zoom=8&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 128,
#       'time': 233,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif',
#       'direction': 4},
#      {'distance': 0.342,
#       'streets': ['Avenida Calle 34'],
#       'narrative': 'Turn right onto Avenida Calle 34.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.069542, 'lat': 4.622971},
#       'index': 4,
#       'formattedTime': '00:01:08',
#       'directionName': 'West',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.622971057891846,-74.06954193115234|marker-5||4.623888969421387,-74.07441711425781|marker-6||&center=4.623430013656616,-74.07197952270508&defaultMarker=none&zoom=12&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 68,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 7},
#      {'distance': 0.052,
#       'streets': ['Avenida General Santander'],
#       'narrative': 'Turn right onto Avenida General Santander.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.074417, 'lat': 4.623889},
#       'index': 5,
#       'formattedTime': '00:00:12',
#       'directionName': 'North',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.623888969421387,-74.07441711425781|marker-6||4.6246161460876465,-74.07424926757812|marker-7||&center=4.624252557754517,-74.07433319091797&defaultMarker=none&zoom=14&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 12,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 1},
#      {'distance': 0.024,
#       'streets': ['Calle 35'],
#       'narrative': 'Turn left onto Calle 35.',
#       'turnType': 6,
#       'startPoint': {'lng': -74.074249, 'lat': 4.624616},
#       'index': 6,
#       'formattedTime': '00:00:04',
#       'directionName': 'West',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://www.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.6246161460876465,-74.07424926757812|marker-7||4.624665260314941,-74.07460021972656|marker-8||&center=4.624640703201294,-74.07442474365234&defaultMarker=none&zoom=15&rand=329481152&session=6285c199-0211-993a-02b4-38ef-0e69ecbaa1d9',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 4,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif',
#       'direction': 7},
#      {'distance': 0,
#       'streets': [],
#       'narrative': 'CALLE 35.',
#       'turnType': -1,
#       'startPoint': {'lng': -74.0746, 'lat': 4.624665},
#       'index': 7,
#       'formattedTime': '00:00:00',
#       'directionName': '',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 0,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-end_sm.gif',
#       'direction': 0}],
#     'hasFerry': False}],
#   'options': {'arteryWeights': [],
#    'cyclingRoadFactor': 1,
#    'timeType': 0,
#    'useTraffic': False,
#    'returnLinkDirections': False,
#    'countryBoundaryDisplay': True,
#    'enhancedNarrative': False,
#    'locale': 'en_US',
#    'tryAvoidLinkIds': [],
#    'drivingStyle': 2,
#    'doReverseGeocode': True,
#    'generalize': -1,
#    'mustAvoidLinkIds': [],
#    'sideOfStreetDisplay': True,
#    'routeType': 'FASTEST',
#    'avoidTimedConditions': False,
#    'routeNumber': 0,
#    'shapeFormat': 'raw',
#    'maxWalkingDistance': -1,
#    'destinationManeuverDisplay': True,
#    'transferPenalty': -1,
#    'narrativeType': 'text',
#    'walkingSpeed': -1,
#    'urbanAvoidFactor': -1,
#    'stateBoundaryDisplay': True,
#    'unit': 'M',
#    'highwayEfficiency': 22,
#    'maxLinkId': 0,
#    'maneuverPenalty': -1,
#    'avoidTripIds': [],
#    'filterZoneFactor': -1,
#    'manmaps': 'true'},
#   'locations': [{'dragPoint': False,
#     'displayLatLng': {'lng': -74.048279, 'lat': 4.676722},
#     'adminArea4': '',
#     'adminArea5': 'Chapinero',
#     'postalCode': '110011',
#     'adminArea1': 'CO',
#     'adminArea3': 'Bogota',
#     'type': 's',
#     'sideOfStreet': 'N',
#     'geocodeQualityCode': 'P1AAA',
#     'adminArea4Type': 'County',
#     'linkId': 53758943,
#     'street': 'Parque de la 93',
#     'adminArea5Type': 'City',
#     'geocodeQuality': 'POINT',
#     'adminArea1Type': 'Country',
#     'adminArea3Type': 'State',
#     'latLng': {'lng': -74.048279, 'lat': 4.676722}},
#    {'dragPoint': False,
#     'displayLatLng': {'lng': -74.07462, 'lat': 4.624525},
#     'adminArea4': '',
#     'adminArea5': 'Teusaquillo',
#     'postalCode': '111311',
#     'adminArea1': 'CO',
#     'adminArea3': 'Bogota',
#     'type': 's',
#     'sideOfStreet': 'N',
#     'geocodeQualityCode': 'B1AAA',
#     'adminArea4Type': 'County',
#     'linkId': 28254156,
#     'street': 'Calle 35',
#     'adminArea5Type': 'City',
#     'geocodeQuality': 'STREET',
#     'adminArea1Type': 'Country',
#     'adminArea3Type': 'State',
#     'latLng': {'lng': -74.07462, 'lat': 4.624525}}],
#   'time': 611,
#   'hasUnpaved': False,
#   'locationSequence': [0, 1],
#   'hasFerry': False},
#  'info': {'statuscode': 0,
#   'copyright': {'imageAltText': '© 2022 MapQuest, Inc.',
#    'imageUrl': 'http://api.mqcdn.com/res/mqlogo.gif',
#    'text': '© 2022 MapQuest, Inc.'},
#   'messages': []}}

# %% [markdown]
# ## [Open Directions API](https://developer.mapquest.com/documentation/open/directions-api)
#
# ### [Route](https://developer.mapquest.com/documentation/open/directions-api/route/get)

# %%
# Parque de la 93
location1 = '4.6767219,-74.0482788'
# Parque Nacional
location2 = '4.6245251,-74.07462'

open_url_directions = f'http://open.mapquestapi.com/directions/v2/route?key={key}&from={location1}&to={location2}'
r_open_url_directions = requests.get(url=open_url_directions)
r_open_url_directions_json = json.loads(r_open_url_directions.text)
r_open_url_directions_json
# Out:
# {'route': {'hasTollRoad': False,
#   'hasBridge': False,
#   'boundingBox': {'lr': {'lng': -74.047066, 'lat': 4.622971},
#    'ul': {'lng': -74.0746, 'lat': 4.67639}},
#   'distance': 4.905,
#   'hasTimedRestriction': False,
#   'hasTunnel': False,
#   'hasHighway': True,
#   'computedWaypoints': [],
#   'routeError': {'errorCode': -400, 'message': ''},
#   'formattedTime': '00:10:11',
#   'sessionId': '6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#   'hasAccessRestriction': False,
#   'realTime': -1,
#   'hasSeasonalClosure': False,
#   'hasCountryCross': False,
#   'fuelUsed': 0.25,
#   'legs': [{'hasTollRoad': False,
#     'hasBridge': False,
#     'destNarrative': 'Proceed to CALLE 35.',
#     'distance': 4.905,
#     'hasTimedRestriction': False,
#     'hasTunnel': False,
#     'hasHighway': True,
#     'index': 0,
#     'formattedTime': '00:10:11',
#     'origIndex': 1,
#     'hasAccessRestriction': False,
#     'hasSeasonalClosure': False,
#     'hasCountryCross': False,
#     'roadGradeStrategy': [[]],
#     'destIndex': 3,
#     'time': 611,
#     'hasUnpaved': False,
#     'origNarrative': 'Go southwest on Carrera 11.',
#     'maneuvers': [{'distance': 0.108,
#       'streets': ['Calle 93A'],
#       'narrative': 'Start out going southeast on Calle 93A toward Carrera 12.',
#       'turnType': 0,
#       'startPoint': {'lng': -74.048462, 'lat': 4.67639},
#       'index': 0,
#       'formattedTime': '00:00:36',
#       'directionName': 'Southeast',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.676390171051025,-74.0484619140625|marker-1||4.675669193267822,-74.04706573486328|marker-2||&center=4.676029682159424,-74.04776382446289&defaultMarker=none&zoom=14&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 36,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-start_sm.gif',
#       'direction': 5},
#      {'distance': 1.507,
#       'streets': ['Carrera 11'],
#       'narrative': 'Turn right onto Carrera 11.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.047066, 'lat': 4.675669},
#       'index': 1,
#       'formattedTime': '00:03:23',
#       'directionName': 'Southwest',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.675669193267822,-74.04706573486328|marker-2||4.657280921936035,-74.05870819091797|marker-3||&center=4.666475057601929,-74.05288696289062&defaultMarker=none&zoom=9&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 203,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 6},
#      {'distance': 0.276,
#       'streets': ['Avenida Chile', 'Calle 72'],
#       'narrative': 'Turn right onto Avenida Chile/Calle 72.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.058708, 'lat': 4.657281},
#       'index': 2,
#       'formattedTime': '00:00:55',
#       'directionName': 'Northwest',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.657280921936035,-74.05870819091797|marker-3||4.659584999084473,-74.06198120117188|marker-4||&center=4.658432960510254,-74.06034469604492&defaultMarker=none&zoom=12&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 55,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 2},
#      {'distance': 2.596,
#       'streets': ['Avenida Caracas'],
#       'narrative': 'Turn left onto Avenida Caracas.',
#       'turnType': 6,
#       'startPoint': {'lng': -74.061981, 'lat': 4.659585},
#       'index': 3,
#       'formattedTime': '00:03:53',
#       'directionName': 'South',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.659584999084473,-74.06198120117188|marker-4||4.622971057891846,-74.06954193115234|marker-5||&center=4.641278028488159,-74.06576156616211&defaultMarker=none&zoom=8&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 128,
#       'time': 233,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif',
#       'direction': 4},
#      {'distance': 0.342,
#       'streets': ['Avenida Calle 34'],
#       'narrative': 'Turn right onto Avenida Calle 34.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.069542, 'lat': 4.622971},
#       'index': 4,
#       'formattedTime': '00:01:08',
#       'directionName': 'West',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.622971057891846,-74.06954193115234|marker-5||4.623888969421387,-74.07441711425781|marker-6||&center=4.623430013656616,-74.07197952270508&defaultMarker=none&zoom=12&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 68,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 7},
#      {'distance': 0.052,
#       'streets': ['Avenida General Santander'],
#       'narrative': 'Turn right onto Avenida General Santander.',
#       'turnType': 2,
#       'startPoint': {'lng': -74.074417, 'lat': 4.623889},
#       'index': 5,
#       'formattedTime': '00:00:12',
#       'directionName': 'North',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.623888969421387,-74.07441711425781|marker-6||4.6246161460876465,-74.07424926757812|marker-7||&center=4.624252557754517,-74.07433319091797&defaultMarker=none&zoom=14&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 12,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_right_sm.gif',
#       'direction': 1},
#      {'distance': 0.024,
#       'streets': ['Calle 35'],
#       'narrative': 'Turn left onto Calle 35.',
#       'turnType': 6,
#       'startPoint': {'lng': -74.074249, 'lat': 4.624616},
#       'index': 6,
#       'formattedTime': '00:00:04',
#       'directionName': 'West',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'mapUrl': 'http://open.mapquestapi.com/staticmap/v5/map?key=PHKj4K2YezeVChykh0blAAAZRapB6OpO&size=225,160&locations=4.6246161460876465,-74.07424926757812|marker-7||4.624665260314941,-74.07460021972656|marker-8||&center=4.624640703201294,-74.07442474365234&defaultMarker=none&zoom=15&rand=45151715&session=6285c19a-00bd-993a-02b4-3874-120e1ca84f01',
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 4,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/rs_left_sm.gif',
#       'direction': 7},
#      {'distance': 0,
#       'streets': [],
#       'narrative': 'CALLE 35.',
#       'turnType': -1,
#       'startPoint': {'lng': -74.0746, 'lat': 4.624665},
#       'index': 7,
#       'formattedTime': '00:00:00',
#       'directionName': '',
#       'maneuverNotes': [],
#       'linkIds': [],
#       'signs': [],
#       'transportMode': 'AUTO',
#       'attributes': 0,
#       'time': 0,
#       'iconUrl': 'http://content.mqcdn.com/mqsite/turnsigns/icon-dirs-end_sm.gif',
#       'direction': 0}],
#     'hasFerry': False}],
#   'options': {'arteryWeights': [],
#    'cyclingRoadFactor': 1,
#    'timeType': 0,
#    'useTraffic': False,
#    'returnLinkDirections': False,
#    'countryBoundaryDisplay': True,
#    'enhancedNarrative': False,
#    'locale': 'en_US',
#    'tryAvoidLinkIds': [],
#    'drivingStyle': 2,
#    'doReverseGeocode': True,
#    'generalize': -1,
#    'mustAvoidLinkIds': [],
#    'sideOfStreetDisplay': True,
#    'routeType': 'FASTEST',
#    'avoidTimedConditions': False,
#    'routeNumber': 0,
#    'shapeFormat': 'raw',
#    'maxWalkingDistance': -1,
#    'destinationManeuverDisplay': True,
#    'transferPenalty': -1,
#    'narrativeType': 'text',
#    'walkingSpeed': -1,
#    'urbanAvoidFactor': -1,
#    'stateBoundaryDisplay': True,
#    'unit': 'M',
#    'highwayEfficiency': 22,
#    'maxLinkId': 0,
#    'maneuverPenalty': -1,
#    'avoidTripIds': [],
#    'filterZoneFactor': -1,
#    'manmaps': 'true'},
#   'locations': [{'dragPoint': False,
#     'displayLatLng': {'lng': -74.048279, 'lat': 4.676722},
#     'adminArea4': '',
#     'adminArea5': 'Chapinero',
#     'postalCode': '110011',
#     'adminArea1': 'CO',
#     'adminArea3': 'Bogota',
#     'type': 's',
#     'sideOfStreet': 'N',
#     'geocodeQualityCode': 'P1AAA',
#     'adminArea4Type': 'County',
#     'linkId': 53758943,
#     'street': 'Parque de la 93',
#     'adminArea5Type': 'City',
#     'geocodeQuality': 'POINT',
#     'adminArea1Type': 'Country',
#     'adminArea3Type': 'State',
#     'latLng': {'lng': -74.048279, 'lat': 4.676722}},
#    {'dragPoint': False,
#     'displayLatLng': {'lng': -74.07462, 'lat': 4.624525},
#     'adminArea4': '',
#     'adminArea5': 'Teusaquillo',
#     'postalCode': '111311',
#     'adminArea1': 'CO',
#     'adminArea3': 'Bogota',
#     'type': 's',
#     'sideOfStreet': 'N',
#     'geocodeQualityCode': 'B1AAA',
#     'adminArea4Type': 'County',
#     'linkId': 28254156,
#     'street': 'Calle 35',
#     'adminArea5Type': 'City',
#     'geocodeQuality': 'STREET',
#     'adminArea1Type': 'Country',
#     'adminArea3Type': 'State',
#     'latLng': {'lng': -74.07462, 'lat': 4.624525}}],
#   'time': 611,
#   'hasUnpaved': False,
#   'locationSequence': [0, 1],
#   'hasFerry': False},
#  'info': {'statuscode': 0,
#   'copyright': {'imageAltText': '© 2022 MapQuest, Inc.',
#    'imageUrl': 'http://api.mqcdn.com/res/mqlogo.gif',
#    'text': '© 2022 MapQuest, Inc.'},
#   'messages': []}}
